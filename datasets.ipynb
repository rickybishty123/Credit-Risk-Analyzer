# %%
import pandas as pd
import numpy as np

# %%
ds1 = pd.read_csv('/home/user/Desktop/Lending Club/Short Datasets/accepted_2007_to_2018Q4-3.csv')
# Out:
# /tmp/ipykernel_512122/2051011383.py:1: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds1 = pd.read_csv('/home/user/Desktop/Lending Club/Short Datasets/accepted_2007_to_2018Q4-3.csv')

# %%
ds1.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
ds1.shape
# Out:
# (660701, 151)

# %%
pd.set_option('display.max_columns', None)
print(ds1.head())
# Out:
#          id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  68407277     3600.0       3600.0           3600.0   36 months     13.99
# 1  68355089    24700.0      24700.0          24700.0   36 months     11.99
# 2  68341763    20000.0      20000.0          20000.0   60 months     10.78
# 3  66310712    35000.0      35000.0          35000.0   60 months     14.85
# 4  68476807    10400.0      10400.0          10400.0   60 months     22.45
#
#    installment grade sub_grade                    emp_title emp_length  \
# 0       123.03     C        C4                      leadman  10+ years
# 1       820.28     C        C1                     Engineer  10+ years
# 2       432.66     B        B4                 truck driver  10+ years
# 3       829.90     C        C5  Information Systems Officer  10+ years
# 4       289.91     F        F1          Contract Specialist    3 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
pd.set_option('display.max_rows', None)
# Calculate the total number of rows
total_rows = len(ds1)

# Calculate the count of null values in each column
null_counts = ds1.isnull().sum()

# Calculate the percentage of null values in each column
null_percentage = (null_counts / total_rows) * 100

# Create a DataFrame to display the results
null_df = pd.DataFrame({'Column Name': null_counts.index, 'Null Count': null_counts.values, 'Null Percentage': null_percentage.values})

# Print the DataFrame with null counts and percentages
print(null_df)
# Out:
#                                     Column Name  Null Count  Null Percentage
# 0                                            id           0         0.000000
# 1                                     member_id      660701       100.000000
# 2                                     loan_amnt          15         0.002270
# 3                                   funded_amnt          15         0.002270
# 4                               funded_amnt_inv          15         0.002270
# 5                                          term          15         0.002270
# 6                                      int_rate          15         0.002270
# 7                                   installment          15         0.002270
# 8                                         grade          15         0.002270
# 9                                     sub_grade          15         0.002270
# 10                                    emp_title       45102         6.826386
# ...

# %%
ds1 = ds1.iloc[:, :-36]

# %%
# List of column names to delete
columns_to_delete = ['member_id', 'desc', 'mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'mths_since_rcnt_il', 'il_util', 'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq', 'url']

# Delete the specified columns
ds1.drop(columns=columns_to_delete, inplace=True)

# %%
# Count of different values in the column
value_counts = ds1['loan_status'].value_counts()

# Total count of values in the column
total_count = len(ds1['loan_status'])

# Print the count and different values
print("Total Count:", total_count)
print("\nCount of Different Values:")
print(value_counts)
# Out:
# Total Count: 660701
#
# Count of Different Values:
# loan_status
# Fully Paid                                             345860
# Current                                                218399
# Charged Off                                             83265
# Late (31-120 days)                                       6655
# In Grace Period                                          2415
# Does not meet the credit policy. Status:Fully Paid       1988
# Late (16-30 days)                                        1327
# Does not meet the credit policy. Status:Charged Off       761
# Default                                                    16
# Name: count, dtype: int64

# %%
# List of specified words you want to replace with 0
specified_words = ['Charged Off', 'Late (31-120 days)', 'Default']

# Replace specified words with 0 in the specified column
ds1['loan_status'] = ds1['loan_status'].replace(specified_words, 0)

# %% [markdown]
# Turning Bad Loans into 0

# %%
# Count of different values in the column
value_counts = ds1['loan_status'].value_counts()

# Total count of values in the column
total_count = len(ds1['loan_status'])

# Print the count and different values
print("Total Count:", total_count)
print("\nCount of Different Values:")
print(value_counts)
# Out:
# Total Count: 660701
#
# Count of Different Values:
# loan_status
# Fully Paid                                             345860
# Current                                                218399
# 0                                                       89936
# In Grace Period                                          2415
# Does not meet the credit policy. Status:Fully Paid       1988
# Late (16-30 days)                                        1327
# Does not meet the credit policy. Status:Charged Off       761
# Name: count, dtype: int64

# %% [markdown]
# Turning Good Loans into 1

# %%
# List of specified words you want to replace with 0
specified_words = ['Fully Paid']

# Replace specified words with 0 in the specified column
ds1['loan_status'] = ds1['loan_status'].replace(specified_words, 1)

# %% [markdown]
# Deleting all the rows containing Current, In Grace Period, Late(16-30 days)

# %%
# Specify the entry you want to remove rows containing
entry_to_remove = 'Current'

# Filter the DataFrame to exclude rows containing the specified entry
ds1 = ds1[ds1['loan_status'] != entry_to_remove]

# %%
# Specify the entry you want to remove rows containing
entry_to_remove = 'In Grace Period'

# Filter the DataFrame to exclude rows containing the specified entry
ds1 = ds1[ds1['loan_status'] != entry_to_remove]

# %%
# Specify the entry you want to remove rows containing
entry_to_remove = 'Late (16-30 days)'

# Filter the DataFrame to exclude rows containing the specified entry
ds1 = ds1[ds1['loan_status'] != entry_to_remove]

# %%
# Specify the entry you want to remove rows containing
entry_to_remove = 'Does not meet the credit policy. Status:Fully Paid'

# Filter the DataFrame to exclude rows containing the specified entry
ds1 = ds1[ds1['loan_status'] != entry_to_remove]

# %%
# Specify the entry you want to remove rows containing
entry_to_remove = 'Does not meet the credit policy. Status:Charged Off'

# Filter the DataFrame to exclude rows containing the specified entry
ds1 = ds1[ds1['loan_status'] != entry_to_remove]

# %%
ds1 = ds1.drop(ds1[ds1['loan_status'] == 'Late (16-30 days)'].index)

# %%
ds1 = ds1.drop(ds1[ds1['loan_status'] == 'Does not meet the credit policy. Status:Fully Paid'].index)

# %%
ds1 = ds1.drop(ds1[ds1['loan_status'] == 'Does not meet the credit policy. Status:Charged Off'].index)

# %%
# Count of different values in the column
value_counts = ds1['loan_status'].value_counts()

# Total count of values in the column
total_count = len(ds1['loan_status'])

# Print the count and different values
print("Total Count:", total_count)
print("\nCount of Different Values:")
print(value_counts)
# Out:
# Total Count: 435811
#
# Count of Different Values:
# loan_status
# 1    345860
# 0     89936
# Name: count, dtype: int64

# %% [markdown]
# Now we have ds_1 containing only 1 and 0 (good and bad loans values)

# %% [markdown]
# We should now select all the bad loans and almost equal number of good loans and then make a new csv file containing this data

# %%
ds1 = ds1.sort_values(by="loan_status")

# %%
ds1.head()
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 5   131344335    18000.0      18000.0          18000.0   36 months     17.47
# 7   130494879     8000.0       8000.0           7975.0   36 months     13.58
# 8   131339159    35000.0      35000.0          35000.0   36 months      9.43
# 9   131352740    15000.0      15000.0          15000.0   36 months      7.34
# 10  131257943    20000.0      20000.0          20000.0   60 months     11.98
#
#     installment grade sub_grade                      emp_title  ...  \
# 5        645.97     D        D1                         Driver  ...
# 7        271.80     C        C2           Applications Analyst  ...
# 8       1120.01     B        B1               Enterprise Sales  ...
# 9        465.50     A        A4  Director of Clinical Services  ...
# 10       444.69     B        B5              Territory Manager  ...
#
#    num_tl_90g_dpd_24m num_tl_op_past_12m  pct_tl_nvr_dlq percent_bc_gt_75  \
# ...

# %% [markdown]
# We can see that Bad Loans are placed before Good Loans in the sorted dataset so if we select almost double the Bad Data rows and make a new table using that then we will have almost an equal number of Good Loand and Bad Loans cases with us

# %%
final_ds1 = ds1.iloc[:200000]

# %% [markdown]
# Exporting the final_ds1 dataset as a csv file

# %%
final_ds1.to_csv('final_dataset_3.csv', index=False)

# %% [markdown]
# We have achieved our target of cleaning the data and finding almost equal number of good and bad loans using this code

# %% [markdown]
# Our output is saved as 3 csv files which have to be compiled into 1, forming the final dataset
